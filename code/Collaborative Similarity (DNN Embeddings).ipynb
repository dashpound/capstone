# %% [markdown]
# ## Similarity Analysis

# %%
from similarity import SimilarityPredictions
from environment_configuration import *

# Import packages
import pickle
import pandas as pd
from pathlib import Path
import gc
# Out:
# Script: 01.01.02 [Import Packages] completed
# Script: 01.01.03 [Update Data Paths] completed
# Script: 01.01.04 [Define Other Global Variables] completed

# %%
#Load clean producs data
products_clean = pd.read_pickle("../data/products_clean_idx.pkl")

# %%
#load collaborative product embeddings
prod_embeddings = pd.read_pickle("../data/product_embeddings_ids_only.pkl")

# %%
def lookup_asin_by_title(prod_title):
    return products_clean[products_clean.title.str.contains(prod_title, case=False)]

# %%
lookup_asin_by_title('xbox')
# Out:
#              asin                                        description  \
# idx
# 54610  B00062NHTS  DVD players, VCRs, DBS receivers, video game s...
# 14464  B0006PY3DY  Developed in conjunction with the Game Audio N...
# 15306  B000812QC6  Get more hookup flexibility for your digital c...
# 31864  B000B525DY  If you have more component video sources than ...
# 16016  B000CCXCYC  Make your Xbox 360&#xAE; part of your home ent...
# ...           ...                                                ...
# 42301  B00FX9WJNO  6ft High Speed HDMI Cable with Ethernet 28 AWG...
# 43870  B00G059G86  The multi-purpose quiet fan can be placed on t...
# 42743  B00G05A2MU  The multi-purpose quiet fan can be placed on t...
# 2923   B00G6IJ5NI
# 13744  B00JO80LUI  This item includes: 1 x Geartist universal cel...
#
#                                                    title  \
# idx
# 54610  Nyrius SW200 S-Video Composite &amp; Digital O...
# 14464  Xbox Spherex 51000 6-Piece 5.1 Surround Sound ...
# 15306  Nyrius SW100 Digital Audio Optical Toslink 3 I...
# 31864  Nyrius SW201 HD Component Video YPbPr &amp; Di...
# 16016  Logitech Harmony Xbox 360 Remote (Discontinued...
# ...                                                  ...
# 42301  HDMI 2 Pack - PREMIUM SERIES GOLD Plated 6 ft ...
# 43870  AC Infinity AI-MPF80A Quiet 80mm USB Fan for R...
# 42743  AC Infinity AI-MPF120A Quiet 120mm USB Fan for...
# 2923   SteelSeries H Wireless Gaming Headset with Dol...
# 13744  Rii i8 Mini 2.4GHz Wireless Touchpad Keyboard ...
#
#                    category2_t                category3_t  \
# idx
# 54610   Accessories & Supplies  Audio & Video Accessories
# 14464  Computers & Accessories       Cables & Accessories
# 15306   Accessories & Supplies  Audio & Video Accessories
# 31864   Accessories & Supplies  Audio & Video Accessories
# 16016   Accessories & Supplies  Audio & Video Accessories
# ...                        ...                        ...
# 42301   Accessories & Supplies  Audio & Video Accessories
# 43870  Computers & Accessories        Computer Components
# 42743  Computers & Accessories        Computer Components
# 2923   Computers & Accessories       Cables & Accessories
# 13744  Computers & Accessories       Cables & Accessories
#
#                    category4_t            category5_t  category6_t  \
# idx
# 54610             Distribution  Selector Switch Boxes      Unknown
# 14464        Computer Speakers                Unknown      Unknown
# 15306             Distribution  Selector Switch Boxes      Unknown
# 31864             Distribution  Selector Switch Boxes      Unknown
# 16016          Remote Controls     TV Remote Controls      Unknown
# ...                        ...                    ...          ...
# 42301   Cables & Interconnects           Video Cables  HDMI Cables
# 43870           Fans & Cooling              Case Fans      Unknown
# 42743           Fans & Cooling              Case Fans      Unknown
# 2923    Headsets & Microphones            PC Headsets      Unknown
# 13744  Keyboard & Mouse Combos                Unknown      Unknown
#
#        hasDescription  price_t  containsAnySalesRank  numberQuestions  \
# idx
# 54610               1    29.97                     0                0
# 14464               1    24.72                     0                5
# 15306               1    19.97                     1               10
# 31864               1    49.99                     0               10
# 16016               1   139.99                     0                9
# ...               ...      ...                   ...              ...
# 42301               1    35.00                     0                8
# 43870               1     9.99                     1                0
# 42743               1    13.99                     1               10
# 2923                1   289.99                     0               10
# 13744               1    12.99                     1               10
#
#        numberReviews  meanStarRating  star1Rating  star2Rating  star3Rating  \
# idx
# 54610           15.0        4.266667     0.066667     0.066667     0.000000
# 14464            6.0        4.333333     0.000000     0.000000     0.166667
# 15306          129.0        3.775194     0.186047     0.046512     0.062016
# 31864           30.0        4.500000     0.033333     0.033333     0.066667
# 16016           67.0        4.268657     0.029851     0.044776     0.104478
# ...              ...             ...          ...          ...          ...
# 42301           20.0        4.850000     0.000000     0.000000     0.050000
# 43870           10.0        4.800000     0.000000     0.000000     0.000000
# 42743           20.0        4.800000     0.000000     0.000000     0.050000
# 2923            41.0        4.146341     0.073171     0.024390     0.121951
# 13744           10.0        4.600000     0.000000     0.100000     0.000000
#
#        star4Rating  star5Rating electronicsRankBin
# idx
# 54610     0.266667     0.600000            Unknown
# 14464     0.333333     0.500000            Unknown
# 15306     0.217054     0.488372            Unknown
# 31864     0.133333     0.733333            Unknown
# 16016     0.268657     0.552239            Unknown
# ...            ...          ...                ...
# 42301     0.050000     0.900000            Unknown
# 43870     0.200000     0.800000            Unknown
# 42743     0.100000     0.850000            Unknown
# 2923      0.243902     0.536585            Unknown
# 13744     0.100000     0.800000            Unknown
#
# [100 rows x 20 columns]

# %% [markdown]
# ### Sklearn similarity compare gives memory error

# %%
def get_detailed_recs(prodIdx, embeddings, comp_type="cosine", file_path=''):
    #convert embeddings to compressed format
    
    #get similar movies
    sim_model = SimilarityPredictions(embeddings, similarity_metric=comp_type)
    output = sim_model.predict_similar_items(seed_item=prodIdx, n=20)
    similar_prods = pd.DataFrame(output)
    similar_prods.set_index('item_id', inplace=True)
    sim_df = pd.merge(products_clean, similar_prods, left_index=True, right_index=True)
    sim_df.sort_values('similarity_score', ascending=False, inplace=True)
    
    #save recs locally
    if(len(file_path)>0):
        sim_df.head(20).to_csv(file_path, index=False, header=True)
        
    return sim_df.head(20)

# %%
gc.collect()
# Out:
# 13419

# %%
#search for Seiki SE50UY04 50-Inch 4K UHD 120Hz LED HDTV
# B00ES5Q6E2 => idx 2411
get_detailed_recs(50295,prod_embeddings[:10000], comp_type="euclidean")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 50295
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-54-9fe2675dd08b> in <module>
#       1 #search for Seiki SE50UY04 50-Inch 4K UHD 120Hz LED HDTV
#       2 # B00ES5Q6E2 => idx 2411
# ----> 3 get_detailed_recs(50295,prod_embeddings[:10000], comp_type="euclidean")
#
# <ipython-input-48-0767ad96996c> in get_detailed_recs(prodIdx, embeddings, comp_type, file_path)
#       4     #get similar movies
#       5     sim_model = SimilarityPredictions(embeddings, similarity_metric=comp_type)
# ----> 6     output = sim_model.predict_similar_items(seed_item=prodIdx, n=20)
#       7     similar_prods = pd.DataFrame(output)
#       8     similar_prods.set_index('item_id', inplace=True)
#
# ~\Google Drive\PREDICT-498 Capstone\GitHub\capstone\code\similarity.py in predict_similar_items(self, seed_item, n)
#      38     def predict_similar_items(self, seed_item, n):
#      39         '''Use the similarity_matrix to return n most similar items.'''
# ---> 40         similar_items = pd.DataFrame(self.similarity_matrix.loc[seed_item])
#      41         similar_items.columns = ["similarity_score"]
#      42         if self.similarity_metric == 'cosine':
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1848         # fall thru to straight lookup
#    1849         self._validate_key(key, axis)
# -> 1850         return self._get_label(key, axis=axis)
#    1851
#    1852
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     158             raise IndexingError("no slices here, handle elsewhere")
#     159
# --> 160         return self.obj._xs(label, axis=axis)
#     161
#     162     def _get_loc(self, key: int, axis: int):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3735             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3736         else:
# -> 3737             loc = self.index.get_loc(key)
#    3738
#    3739             if isinstance(loc, np.ndarray):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 50295

# %%
import numpy as np
np.dot(prod_embeddings[:10000].values, prod_embeddings[:10000].values.T)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-94-23d50cebcd49> in <module>
#       1 import numpy as np
# ----> 2 np.dot(prod_embeddings[:10000].values, prod_embeddings[:10000].values.T)
#
# MemoryError:

# %%
prod_embeddings.shape
# Out:
# (62990, 100)

# %% [markdown]
# ### Try scipy distance calculation

# %%
import scipy.spatial.distance
def cos_cdist(matrix, vector):
    """
    Compute the cosine distances between each row of matrix and vector.
    """
    v = vector.reshape(1, -1)
    return 1-scipy.spatial.distance.cdist(matrix, v, 'cosine').reshape(-1)

# %%
x = prod_embeddings.iloc[54610]
y = cos_cdist(prod_embeddings.values, x.values)

# %%
len(y)
# Out:
# 62990

# %%
sim_results = pd.DataFrame(y, columns=['cdist'])

# %%
sim_results.nlargest(10, 'cdist').round(6)
# Out:
#           cdist
# 54610  1.000000
# 50801  0.747855
# 55528  0.745170
# 3659   0.744890
# 3611   0.743781
# 43329  0.741314
# 12293  0.731471
# 37041  0.724865
# 4937   0.723555
# 10258  0.723492

# %%
products_clean.loc[3659]
# Out:
# asin                                                           B0055QYJIS
# description             Charge your HP TouchPad without wires using th...
# title                            HP Touchstone Charging Dock for TouchPad
# category2_t                                       Computers & Accessories
# category3_t                               Touch Screen Tablet Accessories
# category4_t                                           Chargers & Adapters
# category5_t                                                       Unknown
# category6_t                                                       Unknown
# hasDescription                                                          1
# price_t                                                             39.99
# containsAnySalesRank                                                    0
# numberQuestions                                                        10
# numberReviews                                                         155
# meanStarRating                                                    4.76129
# star1Rating                                                    0.00645161
# star2Rating                                                    0.00645161
# star3Rating                                                     0.0387097
# star4Rating                                                      0.116129
# star5Rating                                                      0.832258
# electronicsRankBin                                                Unknown
# Name: 3659, dtype: object
